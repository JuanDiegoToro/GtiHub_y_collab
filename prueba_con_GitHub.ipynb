# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanDiegoToro/GtiHub_y_collab/blob/nueva_rama/prueba_con_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


#Esto es un ejemplo sobre el uso de Github y Collab
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x,y)
plt.legend('funcion seno')
plt.title('Grafica prueba')
plt.grid()
